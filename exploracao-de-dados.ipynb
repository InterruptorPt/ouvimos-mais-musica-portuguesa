# %%
# importar bibliotecas de software

import pandas as pd
import numpy as np
import musicbrainzngs
from tqdm.notebook import tqdm

# %% [markdown]
# ## Exploração de dados

# %%
charts = pd.read_csv("charts.csv")
charts.dtypes
# Out:
# Unnamed: 0         int64
# Unnamed: 0.1       int64
# rank               int64
# previous_week     object
# artist            object
# album             object
# label             object
# weeks_on_chart     int64
# calendar_week      int64
# year               int64
# dtype: object

# %%
charts = charts.drop(['Unnamed: 0', "Unnamed: 0.1"], axis=1)
charts
# Out:
#        rank previous_week             artist  \
# 0         1             1         Rui Veloso
# 1         2             3    Robbie Williams
# 2         3             2        Tribalistas
# 3         4             4        Linkin Park
# 4         5             6      Tony Carreira
# ...     ...           ...                ...
# 24805    26            35         Pink Floyd
# 24806    27            32  António Variações
# 24807    28            22    João Pedro Pais
# 24808    29            23     Camila Cabello
# 24809    30            18  Jose Mário Branco
#
#                                    album       label  weeks_on_chart  \
# 0                    O concerto acústico      Virgin               8
# 1                       Live Summer 2003   Chrysalis              14
# 2                            Tribalistas         Emi              42
# 3                          Live In Texas          Wb               7
# 4          Ao vivo no pavilhao atlantico    Espacial              22
# ...                                  ...         ...             ...
# 24805                           The Wall      Warner              64
# 24806      O melhor de António Variações      Warner              23
# 24807  Confidências (de um homem vulgar)  Sony Music              10
# 24808                            Romance  Sony Music               3
# 24809                 Canções escolhidas      Warner              11
#
#        calendar_week  year
# 0                  1  2004
# 1                  1  2004
# 2                  1  2004
# 3                  1  2004
# 4                  1  2004
# ...              ...   ...
# 24805             52  2019
# 24806             52  2019
# 24807             52  2019
# 24808             52  2019
# 24809             52  2019
#
# [24810 rows x 8 columns]

# %%
charts.isna().sum()
# Out:
# rank                 0
# previous_week     2475
# artist              55
# album                0
# label               57
# weeks_on_chart       0
# calendar_week        0
# year                 0
# dtype: int64

# %%
charts["artist"].value_counts()
# Out:
# Mariza                     968
# Tony Carreira              641
# Ana Moura                  616
# António Zambujo            412
# Soundtrack                 336
#                           ...
# Pentatonix                   1
# Warpaint                     1
# Panic! At The Disco          1
# Hermínia Silva               1
# Pat Metheny Unity Group      1
# Name: artist, Length: 1114, dtype: int64

# %%
# lista de artistas
unique_artists = list(charts["artist"].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21d9e8ca8403> in <module>
# ----> 1 unique_artists = list(charts["artist"].unique())
#
# NameError: name 'charts' is not defined

# %% [markdown]
# ## Ir buscar nacionalidade dos artistas via MusicBrainz

# %%
musicbrainzngs.auth()
musicbrainzngs.set_useragent("chart", 0.1, "https://rute.radio")

# %%
new_df = pd.DataFrame()

for artist in tqdm(unique_artists):
    artist_list = musicbrainzngs.search_artists(artist=artist)
    artist_df = pd.DataFrame.from_records(artist_list)
    new_df = pd.concat([new_df, artist_df])
    
print("Já está")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1115.0), HTML(value='')))
# Done!!!

# %%
#retirar informação dos dicionários extraídos do musicbrainz


def get_name(x):
    if type(x) == dict:
        return x.get("name")
    
    return "---"

def get_country(x):
    if type(x) == dict:
        return x.get("country")
    
    return "---"
            
new_df["artist"] = new_df["artist-list"].apply(get_name)  
new_df["country"] = new_df["artist-list"].apply(get_country)
new_df
# Out:
#     artist-count                                        artist-list  \
# 0            100  {'id': '758416ad-4871-472a-ab82-fd6e1b7b6c67',...
# 1            100  {'id': 'f07dbc2f-317b-470f-bad4-5f1b0eb6faf1',...
# 2            100  {'id': 'b4082b3e-1e45-4544-8d5b-a5fc367648fa',...
# 3            100  {'id': '55536771-cd1b-455a-afb4-ed3a4b197c8b',...
# 4            100  {'id': 'f1ad854a-3b6f-4f57-b902-a29baa2c9efa',...
# ..           ...                                                ...
# 21         91647  {'id': 'e6181aae-1216-4f8f-9fe3-79222759b42f',...
# 22         91647  {'id': '70a803e5-15db-41bb-861d-ec9af670f323',...
# 23         91647  {'id': '92fc1517-7e49-44a0-9ca2-644e35b424c5',...
# 24         91647  {'id': '8bb66e3d-cf3a-4186-a844-fb1bc7367fcb',...
# 0              1  {'id': '31a72e4a-09e7-4ba2-8928-a08ba0047d53',...
#
#                                      artist country
# 0                                Rui Veloso      PT
# 1                            Caetano Veloso    None
# 2                             Moreno Veloso      BR
# 3                                       RUI    None
# 4                                       Rui    None
# ..                                      ...     ...
# 21        The Reggae Philharmonic Orchestra    None
# 22           Buffalo Philharmonic Orchestra      US
# 23                         BBC Philharmonic    None
# 24  The Royal Philharmonic Chamber Ensemble    None
# 0                                      Elas    None
#
# [23171 rows x 4 columns]

# %%
new_df = new_df.drop(['artist-list', "artist-count"], axis=1)

# %%
new_df.reset_index(inplace=True)
new_df.drop("index", axis=1, inplace = True)

# %%
new_df.drop_duplicates(subset="artist", keep = "first", inplace=True)
new_df
# Out:
#                                         artist country
# 0                                   Rui Veloso      PT
# 1                               Caetano Veloso    None
# 2                                Moreno Veloso      BR
# 3                                          RUI    None
# 4                                          Rui    None
# ...                                        ...     ...
# 23119                             Muri & Mario      DK
# 23138                             Sara Hickman      US
# 23142                             Sara Gazarek      US
# 23169  The Royal Philharmonic Chamber Ensemble    None
# 23170                                     Elas    None
#
# [14030 rows x 2 columns]

# %%
clean_artists  = new_df["artist"].isin(unique_artists)
clean_artists
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 23166    False
# 23167    False
# 23168    False
# 23169    False
# 23170     True
# Name: artist, Length: 23171, dtype: bool

# %%
newish = charts.merge(new_df, how="left", on='artist')

#newish.drop_duplicates(inplace= True)
#newish.reset_index(inplace = True)

newish
# Out:
#        rank previous_week             artist  \
# 0         1             1         Rui Veloso
# 1         2             3    Robbie Williams
# 2         3             2        Tribalistas
# 3         4             4        Linkin Park
# 4         5             6      Tony Carreira
# ...     ...           ...                ...
# 24805    26            35         Pink Floyd
# 24806    27            32  António Variações
# 24807    28            22    João Pedro Pais
# 24808    29            23     Camila Cabello
# 24809    30            18  Jose Mário Branco
#
#                                    album       label  weeks_on_chart  \
# 0                    O concerto acústico      Virgin               8
# 1                       Live Summer 2003   Chrysalis              14
# 2                            Tribalistas         Emi              42
# 3                          Live In Texas          Wb               7
# 4          Ao vivo no pavilhao atlantico    Espacial              22
# ...                                  ...         ...             ...
# 24805                           The Wall      Warner              64
# 24806      O melhor de António Variações      Warner              23
# 24807  Confidências (de um homem vulgar)  Sony Music              10
# 24808                            Romance  Sony Music               3
# 24809                 Canções escolhidas      Warner              11
#
#        calendar_week  year country
# 0                  1  2004      PT
# 1                  1  2004      GB
# 2                  1  2004      BR
# 3                  1  2004      US
# 4                  1  2004      PT
# ...              ...   ...     ...
# 24805             52  2019      GB
# 24806             52  2019      PT
# 24807             52  2019      PT
# 24808             52  2019      US
# 24809             52  2019     NaN
#
# [24810 rows x 9 columns]

# %%
newish.sort_values(by=['calendar_week', 'year', "rank"], inplace=True)
#newish.drop_duplicates(subset="country")
newish
# Out:
#        rank previous_week             artist  \
# 0         1             1         Rui Veloso
# 1         2             3    Robbie Williams
# 2         3             2        Tribalistas
# 3         4             4        Linkin Park
# 4         5             6      Tony Carreira
# ...     ...           ...                ...
# 24805    26            35         Pink Floyd
# 24806    27            32  António Variações
# 24807    28            22    João Pedro Pais
# 24808    29            23     Camila Cabello
# 24809    30            18  Jose Mário Branco
#
#                                    album       label  weeks_on_chart  \
# 0                    O concerto acústico      Virgin               8
# 1                       Live Summer 2003   Chrysalis              14
# 2                            Tribalistas         Emi              42
# 3                          Live In Texas          Wb               7
# 4          Ao vivo no pavilhao atlantico    Espacial              22
# ...                                  ...         ...             ...
# 24805                           The Wall      Warner              64
# 24806      O melhor de António Variações      Warner              23
# 24807  Confidências (de um homem vulgar)  Sony Music              10
# 24808                            Romance  Sony Music               3
# 24809                 Canções escolhidas      Warner              11
#
#        calendar_week  year country
# 0                  1  2004      PT
# 1                  1  2004      GB
# 2                  1  2004      BR
# 3                  1  2004      US
# 4                  1  2004      PT
# ...              ...   ...     ...
# 24805             52  2019      GB
# 24806             52  2019      PT
# 24807             52  2019      PT
# 24808             52  2019      US
# 24809             52  2019     NaN
#
# [24810 rows x 9 columns]

# %%
newish.reset_index(inplace = True)
newish.drop("index", axis=1, inplace = True)

# %%
newish.head(55)
# Out:
#     rank previous_week                          artist  \
# 0      1             1                      Rui Veloso
# 1      2             3                 Robbie Williams
# 2      3             2                     Tribalistas
# 3      4             4                     Linkin Park
# 4      5             6                   Tony Carreira
# 5      6            11           Red Hot Chili Peppers
# 6      7             5  Ennio Morricone & Dulce Pontes
# 7      8             7                      Maria Rita
# 8      9             9                   Luís Represas
# 9     10            10                  Julio Iglesias
# 10    11            14                            Dido
# 11    12            15                          R.E.M.
# 12    13            12                  Caetano Veloso
# 13    14            13                 Pedro Abrunhosa
# 14    15             8                          Mariza
# 15    16            19                  Britney Spears
# 16    17            24                  Fernando Rocha
# 17    18            16                     Evanescence
# 18    19            20          Frei Hermano Da Camara
# 19    20            30                Enrique Iglesias
# 20    21           NaN                Martinho Da Vila
# 21    22            17                          Camané
# 22    23            22                          Mariza
# 23    24            18                  Roberto Carlos
# 24    25            23                   Avril Lavigne
# 25    26            27                       Pearl Jam
# 26    27            28               Bruce Springsteen
# 27    28            26                           Sting
# 28    29           NaN                         Delfins
# 29    30            ++                         Reamonn
# 30     1             2                         Humanos
# 31     2             1                            Seal
# 32     3             4                    Phil Collins
# 33     4             3                              U2
# 34     5             7                 Robbie Williams
# 35     6             6                     Evanescence
# 36     7             8                       Da Weasel
# 37     8            10                            Blue
# 38     9            14             Jay-Z / Linkin Park
# 39    10             5                     Marco Paulo
# 40    11             9                     Tina Turner
# 41    12            11                  Britney Spears
# 42    13            20                          O-Zone
# 43    14            15                 João Pedro Pais
# 44    15            18                             Era
# 45    16            12                        Maroon 5
# 46    17            29                   Tony Carreira
# 47    18            25                     Os Patinhos
# 48    19            17                        The Gift
# 49    20            13             Adriana Calcanhotto
# 50    21            19                  Russell Watson
# 51    22            22                       Pearl Jam
# 52    23            ++                           Queen
# 53    24            24       Zeze Di Camargo & Luciano
# 54    25            23                          Eminem
#
#                                         album             label  \
# 0                         O concerto acústico            Virgin
# 1                            Live Summer 2003         Chrysalis
# 2                                 Tribalistas               Emi
# 3                               Live In Texas                Wb
# 4               Ao vivo no pavilhao atlantico          Espacial
# 5                               Greatest Hits                Wb
# 6                                       Focus           Polydor
# 7                                  Maria Rita               Wmb
# 8                                 Fora de mão           Mercury
# 9                                    Divorcio          Columbia
# 10                              Life For Rent            Arista
# 11       The Best Of R.E.M. In Time 1988-2003                Wb
# 12                                 Anthologia            Emarcy
# 13                                      Palco           Polydor
# 14                                 Fado curvo            Virgin
# 15                                In The Zone              Jive
# 16                          Portugal a rir! 4          Espacial
# 17                                     Fallen           Wind-up
# 18                   Vivo d'arte, vivo d'amor      Farol Musica
# 19                                          7        Interscope
# 20                                   Conexoes         Som Livre
# 21                 Como sempre... Como dantes           Capitol
# 22                                Fado em mim  World Connection
# 23                                 Pra sempre          Columbia
# 24                                   My World            Arista
# 25                                  Lost Dogs              Epic
# 26                              The Essential          Columbia
# 27                                Sacred Love        Interscope
# 28                 O caminho da felicidade II     Farol  /  Bmg
# 29                              Beautiful Sky            Virgin
# 30                                    Humanos           Capitol
# 31                             Best 1991-2004                Wb
# 32  Love Songs - A Compilation... Old And New                Wb
# 33            How To Dismantle An Atomic Bomb    Island Records
# 34                              Greatest Hits           Capitol
# 35                          Anywhere But Home           Wind Up
# 36                              Re-Definições            Virgin
# 37                               Best Of Blue            Virgin
# 38                           Collision Course               Wbr
# 39                            Amor sem limite       Zona Musica
# 40                               All The Best               Emi
# 41              Greatest Hits: My Prerogative             Zomba
# 42                                 DiscO-Zone            2dance
# 43                                   Tudo bem           Popular
# 44                           The Very Best Of           Mercury
# 45                           Songs About Jane         J Records
# 46                         Vagabundo por amor          Espacial
# 47                    Canções da nossa escola           Vidisco
# 48                                    AM - FM  La Folie Records
# 49                          Adriana partimpim            Ariola
# 50                               Amore musica              Deca
# 51   Rearviewmirror (Greatest Hits 1991-2003)              Epic
# 52           Queen On Fire - Live At The Bowl               Emi
# 53                       Saudade: O melhor de          Columbia
# 54                                     Encore        Interscope
#
#     weeks_on_chart  calendar_week  year country
# 0                8              1  2004      PT
# 1               14              1  2004      GB
# 2               42              1  2004      BR
# 3                7              1  2004      US
# 4               22              1  2004      PT
# 5                7              1  2004      US
# 6               11              1  2004     NaN
# 7                9              1  2004      BR
# 8               10              1  2004      PT
# 9               10              1  2004      ES
# 10              14              1  2004      GB
# 11              10              1  2004      US
# 12               6              1  2004    None
# 13               6              1  2004      PT
# 14              40              1  2004      PT
# 15               7              1  2004      US
# 16               2              1  2004      PT
# 17              33              1  2004      US
# 18               3              1  2004     NaN
# 19               4              1  2004      ES
# 20               1              1  2004     NaN
# 21               4              1  2004      PT
# 22              62              1  2004      PT
# 23               3              1  2004      BR
# 24               4              1  2004      CA
# 25               8              1  2004      US
# 26               8              1  2004      US
# 27              15              1  2004      GB
# 28               1              1  2004    None
# 29               7              1  2004      DE
# 30               4              1  2005      PT
# 31               7              1  2005    None
# 32              14              1  2005      GB
# 33               6              1  2005      IE
# 34              11              1  2005      GB
# 35               6              1  2005      US
# 36              32              1  2005      PT
# 37               6              1  2005      GB
# 38               3              1  2005     NaN
# 39               5              1  2005    None
# 40               9              1  2005      US
# 41               8              1  2005      US
# 42              20              1  2005      MD
# 43               4              1  2005      PT
# 44               2              1  2005      FR
# 45              14              1  2005      US
# 46              21              1  2005      PT
# 47               7              1  2005     NaN
# 48               5              1  2005      PT
# 49              27              1  2005      BR
# 50              10              1  2005      GB
# 51               5              1  2005      US
# 52               8              1  2005      GB
# 53               3              1  2005     NaN
# 54               8              1  2005    None

# %%
newish["artist"].value_counts()
# Out:
# Mariza                                                 968
# Tony Carreira                                          641
# Ana Moura                                              616
# António Zambujo                                        412
# Soundtrack                                             336
#                                                       ...
# Panda e os caricas                                       1
# Mac DeMarco                                              1
# Red Hot Chili Peppers                                    1
# Coro Gulkbenkian, Orquestra Metropolitana De Lisboa      1
# Pat Metheny Unity Group                                  1
# Name: artist, Length: 1114, dtype: int64

# %%
newish.head()
# Out:
#    rank previous_week           artist                          album  \
# 0     1             1       Rui Veloso            O concerto acústico
# 1     2             3  Robbie Williams               Live Summer 2003
# 2     3             2      Tribalistas                    Tribalistas
# 3     4             4      Linkin Park                  Live In Texas
# 4     5             6    Tony Carreira  Ao vivo no pavilhao atlantico
#
#        label  weeks_on_chart  calendar_week  year country
# 0     Virgin               8              1  2004      PT
# 1  Chrysalis              14              1  2004      GB
# 2        Emi              42              1  2004      BR
# 3         Wb               7              1  2004      US
# 4   Espacial              22              1  2004      PT

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation
# Out:
#        rank previous_week                                       artist  \
# 6         7             5               Ennio Morricone & Dulce Pontes
# 18       19            20                       Frei Hermano Da Camara
# 31        2             1                                         Seal
# 38        9            14                          Jay-Z / Linkin Park
# 54       25            23                                       Eminem
# ...     ...           ...                                          ...
# 24787     8             7                              Carlos Do Carmo
# 24794    15            11  André Rieu And His Johann Strauss Orchestra
# 24801    22            25                           Panda e Os Caricas
# 24802    23            34                           Panda e Os Caricas
# 24809    30            18                            Jose Mário Branco
#
#                                            album         label  \
# 6                                          Focus       Polydor
# 18                      Vivo d'arte, vivo d'amor  Farol Musica
# 31                                Best 1991-2004            Wb
# 38                              Collision Course           Wbr
# 54                                        Encore    Interscope
# ...                                          ...           ...
# 24787                                    Oitenta     Universal
# 24794                                 Happy Days     Universal
# 24801         Era uma vez...  Panda e Os Caricas     Universal
# 24802  Brinca e aprende com o Panda e Os Caricas     Universal
# 24809                         Canções escolhidas        Warner
#
#        weeks_on_chart  calendar_week  year country
# 6                  11              1  2004     NaN
# 18                  3              1  2004     NaN
# 31                  7              1  2005    None
# 38                  3              1  2005     NaN
# 54                  8              1  2005    None
# ...               ...            ...   ...     ...
# 24787              18             52  2019     NaN
# 24794               5             52  2019     NaN
# 24801              23             52  2019    None
# 24802               2             52  2019    None
# 24809              11             52  2019     NaN
#
# [5676 rows x 9 columns]

# %%
#adicionar nacionalidades manualmente

newish.loc[newish['artist'] == 'Caetano Veloso', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Martinho Da Vila', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Marco Paulo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Delfins', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Os Patinhos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Frei Hermano Da Camara', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Zeze Di Camargo & Luciano', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Jose Mário Branco', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Panda e Os Caricas', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Carlos Do Carmo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Eminem', 'country'] = 'US'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation
# Out:
#        rank previous_week                                       artist  \
# 6         7             5               Ennio Morricone & Dulce Pontes
# 31        2             1                                         Seal
# 38        9            14                          Jay-Z / Linkin Park
# 60        1             1                                        D'ZRT
# 72       13            17                 Dire Straits & Mark Knopfler
# ...     ...           ...                                          ...
# 24777    28           NaN                                         Zayn
# 24782     3             5                       Camané & Mário Laginha
# 24783     4             4                                         Elas
# 24786     7             9                    Nick Cave & The Bad Seeds
# 24794    15            11  André Rieu And His Johann Strauss Orchestra
#
#                                       album         label  weeks_on_chart  \
# 6                                     Focus       Polydor              11
# 31                           Best 1991-2004            Wb               7
# 38                         Collision Course           Wbr               3
# 60                      Ao vivo no Coliseus  Farol Musica               4
# 72     Private Investigations - The Best Of       Mercury               8
# ...                                     ...           ...             ...
# 24777                          Icarus Falls    Sony Music               1
# 24782                Aqui está-se sossegado        Warner               6
# 24783                                     9    Sony Music               4
# 24786                              Ghosteen      Popstock               8
# 24794                            Happy Days     Universal               5
#
#        calendar_week  year country
# 6                  1  2004     NaN
# 31                 1  2005    None
# 38                 1  2005     NaN
# 60                 1  2006     NaN
# 72                 1  2006     NaN
# ...              ...   ...     ...
# 24777             52  2018     NaN
# 24782             52  2019     NaN
# 24783             52  2019    None
# 24786             52  2019     NaN
# 24794             52  2019     NaN
#
# [5274 rows x 9 columns]

# %%
newish.loc[newish['artist'] == 'Seal', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Nick Cave & The Bad Seeds', 'country'] = 'AU'
newish.loc[newish['artist'] == 'Elas', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Camané & Mário Laginha', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Zayn', 'country'] = 'GB'
newish.loc[newish['artist'] == 'André Rieu And His Johann Strauss Orchestra', 'country'] = 'NL'
newish.loc[newish['artist'] == 'Dire Straits & Mark Knopfler', 'country'] = 'GB'
newish.loc[newish['artist'] == 'D\'ZRT', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Jay-Z / Linkin Park', 'country'] = 'US'
newish.loc[newish['artist'] == 'Ennio Morricone & Dulce Pontes', 'country'] = 'IT/PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation
# Out:
#        rank previous_week                                             artist  \
# 80       21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 90        1             1                                            4 Taste
# 91        2             2                                       André Sardet
# 93        4             5                                         Floribella
# 102      13            15                                          Docemania
# ...     ...           ...                                                ...
# 24754     5             4            Soundtrack / Lady Gaga / Bradley Cooper
# 24763    14            19                    António Zambujo & Miguel Araújo
# 24764    15            16                                         Rosebonbon
# 24770    21            21                                     Raquel Tavares
# 24776    27            29                         Tony Bennett & Diana Krall
#
#                                    album           label  weeks_on_chart  \
# 80                       Christmas Songs           Verve               9
# 90                               4 Taste    Farol Musica               0
# 91                              Acústico    Farol Musica               0
# 93                        O melhor natal       Som Livre               0
# 102                            Docemania       Universal               0
# ...                                  ...             ...             ...
# 24754                     A Star Is Born       Universal              12
# 24763     28 noites ao vivo nos coliseus       Universal              29
# 24764                         Rosebonbon      Sony Music               3
# 24770  Roberto Carlos por Raquel Tavares      Sony Music              57
# 24776               Love Is Here To Stay  Sony/universal              15
#
#        calendar_week  year country
# 80                 1  2006     NaN
# 90                 1  2007     NaN
# 91                 1  2007    None
# 93                 1  2007    None
# 102                1  2007     NaN
# ...              ...   ...     ...
# 24754             52  2018     NaN
# 24763             52  2018     NaN
# 24764             52  2018     NaN
# 24770             52  2018    None
# 24776             52  2018     NaN
#
# [4957 rows x 9 columns]

# %%
newish.loc[newish['artist'] == 'Tony Bennett & Diana Krall', 'country'] = 'US'
newish.loc[newish['artist'] == '4 Taste', 'country'] = 'PT'
newish.loc[newish['artist'] == 'André Sardet', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Floribella', 'country'] = 'PT'
newish.loc[newish['artist'] == 'António Zambujo & Miguel Araújo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Raquel Tavares', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rosebonbon', 'country'] = 'PT'
newish.loc[newish['artist'] == 'D\'ZRT', 'country'] = 'PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#      rank previous_week                                             artist  \
# 80     21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 102    13            15                                          Docemania
# 105    16           NaN                                               Beto
# 110    21            30                                         Bebé Lilly
# 114    25            29                                  Rouxinol Faduncho
# 116    27            18                                        Sam The Kid
# 119    30            20                         Anabela & Carlos Guilherme
# 120     1             1                                         Just Girls
# 122     3             5                                    Vanessa Da Mata
# 127     8             6                    Mafalda Veiga & João Pedro Pais
# 134    15            12                                       Avô Cantigas
# 151     2             2                                         Just Girls
# 164    15            16                                       Leandro [PT]
# 167    18            13                                 Panda vai à escola
# 179    30            28                                 Caixinha de Sonhos
# 181     2             1             Mário Branco - Sérgio Godinho - Fausto
# 186     7             6                                     Rua da Saudade
# 191    12            19                                       Leandro [PT]
# 201    22            27                       Soundtrack / Michael Jackson
# 203    24            23                     Rodrigo Leão & Cinema Ensemble
# 208    29            25                           Soundtrack / Miley Cyrus
# 215     6            20                                               Beto
# 217     8            18                                       Leandro [PT]
# 219    10             9                                         Aurea [PT]
# 224    15            ++                                       Chave d'Ouro
# 227    18             7                Carlos do Carmo & Bernardo Sassetti
# 232    23            12                             Thirty Seconds To Mars
# 233    24            28                                         Ar De Rock
# 235    26            22                                            Rihanna
# 237    28            10  Sting feat. The Royal Philharmonic Concert Orc...
#
#                                    album             label  weeks_on_chart  \
# 80                       Christmas Songs             Verve               9
# 102                            Docemania         Universal               0
# 105                      Porto de abrigo       Zona Musica               0
# 110                   Este e o meu mundo          Sony Bmg               0
# 114                              Best Of         Som Livre               0
# 116                       Pratica(mente)              Edel               0
# 119                             Encontro  Som Livre / Zona               0
# 120                           Just Girls      Farol Musica               5
# 122                                  SIM          Sony Bmg              22
# 127                          Lado a lado    Som Livre / Vc              34
# 134               Fantasminha brincalhão          Sony Bmg              33
# 151                             Play Me!      Farol Musica               5
# 164                        Tudo por amor          Espacial               6
# 167                   Panda vai à escola         Universal               9
# 179          O melhor da música infantil           Vidisco               8
# 181                 Três cantos: Ao vivo               Emi               4
# 186            Canções de Ary dos Santos      Farol Musica               6
# 191                            Também eu          Espacial               5
# 201                           This Is It        Sony Music               9
# 203                                A mãe        Sony Music              27
# 208           Hannah Montana - The Movie               Emi              32
# 215                  Memórias esquecidas      Farol Musica               6
# 217         Ao vivo no coliseu de Lisboa          Espacial               9
# 219                                Aurea        Sony Music               8
# 224                       Pai da criança          Espacial              17
# 227  Carlos do Carmo & Bernardo Sassetti         Universal               7
# 232                          This Is War               Emi               9
# 233                           Ar De Rock           Vidisco               5
# 235                                 Loud         Universal               7
# 237                       Live In Berlin         Universal               5
#
#      calendar_week  year country
# 80               1  2006     NaN
# 102              1  2007     NaN
# 105              1  2007    None
# 110              1  2007     NaN
# 114              1  2007    None
# 116              1  2007     NaN
# 119              1  2007     NaN
# 120              1  2008    None
# 122              1  2008     NaN
# 127              1  2008     NaN
# 134              1  2008    None
# 151              1  2009    None
# 164              1  2009     NaN
# 167              1  2009     NaN
# 179              1  2009     NaN
# 181              1  2010     NaN
# 186              1  2010     NaN
# 191              1  2010     NaN
# 201              1  2010     NaN
# 203              1  2010     NaN
# 208              1  2010     NaN
# 215              1  2011    None
# 217              1  2011     NaN
# 219              1  2011     NaN
# 224              1  2011     NaN
# 227              1  2011     NaN
# 232              1  2011     NaN
# 233              1  2011     NaN
# 235              1  2011    None
# 237              1  2011     NaN

# %%
newish.loc[newish['artist'] == 'Docemania', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Beto', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Bebé Lilly', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rouxinol Faduncho', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Sam The Kid', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Anabela & Carlos Guilherme', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Just Girls', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mafalda Veiga & João Pedro Pais', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Caixinha de Sonhos', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Panda vai à escola', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rua da Saudade', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Leandro [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rodrigo Leão & Cinema Ensemble', 'country'] = 'PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#      rank previous_week                                             artist  \
# 80     21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 122     3             5                                    Vanessa Da Mata
# 134    15            12                                       Avô Cantigas
# 181     2             1             Mário Branco - Sérgio Godinho - Fausto
# 201    22            27                       Soundtrack / Michael Jackson
# 208    29            25                           Soundtrack / Miley Cyrus
# 232    23            12                             Thirty Seconds To Mars
# 237    28            10  Sting feat. The Royal Philharmonic Concert Orc...
# 239    30            ++                                      Kings Of Leon
# 276     7            12                               Maria de Vasconcelos
# 291    22            28                                       Xana Toc Toc
# 297    28            ++                                       Xana Toc Toc
# 302     3             3                    Pedro Abrunhosa & Comité Caviar
# 312    13            14                                                NaN
# 315    16            28                                       Xana Toc Toc
# 319    20            26                               Maria de Vasconcelos
# 333     4             8                                           D.A.M.A.
# 365     6             8                                           D.A.M.A.
# 374    15            14                       Jorge Palma & Sérgio Godinho
# 381    22            16                                           D.A.M.A.
# 388    29            38                                           C4 Pedro
# 389    30            37                                 Jardim De Infância
# 395     6             7   Rancho De Cantadores De Aldeia Nova De São Bento
# 403    14            12                                           D.A.M.A.
# 418    29            41                                  Panda E Os Amigos
# 422     3             3                                           D.A.M.A.
# 423     4             6                                  Maria Vasconcelos
# 426     7            13                                             Calema
# 433    14            14                                  Paulo De Carvalho
# 440    21            32                                             Virgul
#
#                                                  album             label  \
# 80                                     Christmas Songs             Verve
# 122                                                SIM          Sony Bmg
# 134                             Fantasminha brincalhão          Sony Bmg
# 181                               Três cantos: Ao vivo               Emi
# 201                                         This Is It        Sony Music
# 208                         Hannah Montana - The Movie               Emi
# 232                                        This Is War               Emi
# 237                                     Live In Berlin         Universal
# 239                                Come Around Sundown        Sony Music
# 276                                As cançoes da Maria          Arthouse
# 291                                   A festa é nossa!         Universal
# 297                                       Xana Toc Toc         Universal
# 302                                          Contramão         Universal
# 312                                 Unorthodox Jukebox            Warner
# 315                                 Na aldeia colorida         Universal
# 319                             As cançoes da Maria II               Evc
# 333                           Uma questão de princípio        Sony Music
# 365                                   Dá-me um segundo        Sony Music
# 374                  Juntos - Ao vivo no Theatro Circo  Universal/warner
# 381                           Uma questão de princípio        Sony Music
# 388                                          King Ckwa        Sony Music
# 389                                 Jardim De Infância          Espacial
# 395   Rancho De Cantadores De Aldeia Nova De São Bento         Universal
# 403                                   Dá-me um segundo        Sony Music
# 418                                  Panda E Os Amigos         Universal
# 422                                        Lado a lado        Sony Music
# 423  As canções da Maria - Especial história de Por...        Sony Music
# 426                                        A nossa vez        Sony Music
# 433                                             Duetos         Universal
# 440                                      Saber aceitar            Warner
#
#      weeks_on_chart  calendar_week  year country
# 80                9              1  2006     NaN
# 122              22              1  2008     NaN
# 134              33              1  2008    None
# 181               4              1  2010     NaN
# 201               9              1  2010     NaN
# 208              32              1  2010     NaN
# 232               9              1  2011     NaN
# 237               5              1  2011     NaN
# 239               6              1  2011     NaN
# 276              44              1  2013     NaN
# 291               7              1  2013     NaN
# 297              38              1  2013     NaN
# 302               5              1  2014     NaN
# 312               8              1  2014     NaN
# 315               6              1  2014     NaN
# 319              14              1  2014     NaN
# 333              14              1  2015    None
# 365              15              1  2016    None
# 374               9              1  2016     NaN
# 381              70              1  2016    None
# 388              13              1  2016    None
# 389               0              1  2016     NaN
# 395               6              1  2017     NaN
# 403              63              1  2017    None
# 418              32              1  2017     NaN
# 422               6              1  2018    None
# 423               9              1  2018     NaN
# 426              11              1  2018    None
# 433              30              1  2018     NaN
# 440               6              1  2018    None

# %%
newish.loc[newish['artist'] == 'Panda E Os Amigos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Paulo De Carvalho', 'country'] = 'PT'
newish.loc[newish['artist'] == 'D.A.M.A.', 'country'] = 'PT'
newish.loc[newish['artist'] == 'C4 Pedro', 'country'] = 'AN'

newish.loc[newish['artist'] == 'Calema', 'country'] = 'STP'
newish.loc[newish['artist'] == 'Jorge Palma & Sérgio Godinho', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria de Vasconcelos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Pedro Abrunhosa & Comité Caviar', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Xana Toc Toc', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Virgul', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Rancho De Cantadores De Aldeia Nova De São Bento', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mário Branco - Sérgio Godinho - Fausto', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Vanessa Da Mata', 'country'] = 'BR'

newish.loc[newish['artist'] == 'Thirty Seconds To Mars', 'country'] = 'US'
newish.loc[newish['artist'] == 'Kings Of Leon', 'country'] = 'US'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#      rank previous_week                                             artist  \
# 80     21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 134    15            12                                       Avô Cantigas
# 201    22            27                       Soundtrack / Michael Jackson
# 208    29            25                           Soundtrack / Miley Cyrus
# 237    28            10  Sting feat. The Royal Philharmonic Concert Orc...
# 312    13            14                                                NaN
# 389    30            37                                 Jardim De Infância
# 423     4             6                                  Maria Vasconcelos
# 452     3             5            Soundtrack / Lady Gaga / Bradley Cooper
# 462    13             4                                 Soundtrack / Queen
# 472    23            ++                                    Dino D'Santiago
# 473    24            37                                  Maria Vasconcelos
# 475    26            42                                  Twenty One Pilots
# 504    25            ++                                        Carla Bruni
# 537    28            ++                 Elis Regina & Antonio Carlos Jobim
# 577     8           NaN                                      Os Pintainhos
# 593    24           NaN                                             Pigloo
# 609    10            15                                       Avô Cantigas
# 656    27            ++                                               Lucy
# 678    19            22                       Soundtrack / Michael Jackson
# 686    27           NaN                                      Beto & Ménito
# 689    30           NaN                                         Vasco [PT]
# 743    24            ++                                       Pedro Osório
# 769    20            ++                                      Herois do Mar
# 791    12            13                                                NaN
# 867    28           NaN                                 Vinicius De Moraes
# 901     2             4                                  Maria Vasconcelos
# 925    26            ++                                      Guns N' Roses
# 934     5             3            Soundtrack / Lady Gaga / Bradley Cooper
# 937     8            13                                 Soundtrack / Queen
#
#                                                  album            label  \
# 80                                     Christmas Songs            Verve
# 134                             Fantasminha brincalhão         Sony Bmg
# 201                                         This Is It       Sony Music
# 208                         Hannah Montana - The Movie              Emi
# 237                                     Live In Berlin        Universal
# 312                                 Unorthodox Jukebox           Warner
# 389                                 Jardim De Infância         Espacial
# 423  As canções da Maria - Especial história de Por...       Sony Music
# 452                                     A Star Is Born        Universal
# 462                                  Bohemian Rhapsody        Universal
# 472                                         Mundu nôbu       Sony Music
# 473  As canções da Maria - Especial história de Por...       Sony Music
# 475                                             Trench           Warner
# 504                                  Quelqu'un m'a dit            Naive
# 537                                         Elis & Tom        Som Livre
# 577                                      Os Pintainhos     Farol Musica
# 593                                        La banquise          Vidisco
# 609                             Fantasminha brincalhão         Sony Bmg
# 656                                               Lucy            Iplay
# 678                                         This Is It       Sony Music
# 686                          Cumplicidade a duas vozes     Farol Musica
# 689                                O Vasco é boa onda!              Emi
# 743                                Cantos da Babilónia  Compact Records
# 769                                      Herois do Mar              Emi
# 791                                 Unorthodox Jukebox           Warner
# 867                                           Vinicius           Warner
# 901  As canções da Maria - Especial história de Por...       Sony Music
# 925                                      Greatest Hits        Universal
# 934                                     A Star Is Born        Universal
# 937                                  Bohemian Rhapsody        Universal
#
#      weeks_on_chart  calendar_week  year country
# 80                9              1  2006     NaN
# 134              33              1  2008    None
# 201               9              1  2010     NaN
# 208              32              1  2010     NaN
# 237               5              1  2011     NaN
# 312               8              1  2014     NaN
# 389               0              1  2016     NaN
# 423               9              1  2018     NaN
# 452              13              1  2019     NaN
# 462              11              1  2019     NaN
# 472               6              1  2019     NaN
# 473              61              1  2019     NaN
# 475              12              1  2019     NaN
# 504              21              2  2004    None
# 537               5              2  2005     NaN
# 577               0              2  2007     NaN
# 593               0              2  2007    None
# 609              34              2  2008    None
# 656               6              2  2009    None
# 678              10              2  2010     NaN
# 686               1              2  2010     NaN
# 689               1              2  2010     NaN
# 743               3              2  2012     NaN
# 769               6              2  2013     NaN
# 791               9              2  2014     NaN
# 867               1              2  2016     NaN
# 901              10              2  2018     NaN
# 925              21              2  2018     NaN
# 934              14              2  2019     NaN
# 937              12              2  2019     NaN

# %%
newish.loc[newish['artist'] == 'Maria Vasconcelos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Vasco [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Pedro Osório', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Lucy', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Avô Cantigas', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria de Vasconcelos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Elis Regina & Antonio Carlos Jobim', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Herois do Mar', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Vinicius De Moraes', 'country'] = 'BR'

newish.loc[newish['artist'] == 'Pigloo', 'country'] = 'FR'
newish.loc[newish['artist'] == 'Carla Bruni', 'country'] = 'FR'
newish.loc[newish['artist'] == 'Vanessa Da Mata', 'country'] = 'BR'

newish.loc[newish['artist'] == 'Guns N\' Roses', 'country'] = 'US'
newish.loc[newish['artist'] == 'Dino D\'Santiago', 'country'] = 'PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#       rank previous_week                                             artist  \
# 80      21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 201     22            27                       Soundtrack / Michael Jackson
# 208     29            25                           Soundtrack / Miley Cyrus
# 237     28            10  Sting feat. The Royal Philharmonic Concert Orc...
# 312     13            14                                                NaN
# 389     30            37                                 Jardim De Infância
# 452      3             5            Soundtrack / Lady Gaga / Bradley Cooper
# 462     13             4                                 Soundtrack / Queen
# 475     26            42                                  Twenty One Pilots
# 577      8           NaN                                      Os Pintainhos
# 678     19            22                       Soundtrack / Michael Jackson
# 686     27           NaN                                      Beto & Ménito
# 791     12            13                                                NaN
# 934      5             3            Soundtrack / Lady Gaga / Bradley Cooper
# 937      8            13                                 Soundtrack / Queen
# 959     30            ++                                             Márcia
# 1055     6             8                                      Os Pintainhos
# 1068    19           NaN                                          Tom Jobim
# 1098    19            ++                                               Viky
# 1161    22            27                                      Beto & Ménito
# 1164    25            19                       Soundtrack / Michael Jackson
# 1193    24            ++                          Soundtrack / Eddie Vedder
# 1218    19            ++                             Soundtrack / Pearl Jam
# 1247    18            ++                                                NaN
# 1248    19            ++                                                NaN
# 1251    22            ++                                                NaN
# 1252    23           NaN                                        Yo La Tengo
# 1253    24            ++                                                NaN
# 1254    25            ++                                                NaN
# 1258    29            ++                                                NaN
#
#                            album         label  weeks_on_chart  calendar_week  \
# 80               Christmas Songs         Verve               9              1
# 201                   This Is It    Sony Music               9              1
# 208   Hannah Montana - The Movie           Emi              32              1
# 237               Live In Berlin     Universal               5              1
# 312           Unorthodox Jukebox        Warner               8              1
# 389           Jardim De Infância      Espacial               0              1
# 452               A Star Is Born     Universal              13              1
# 462            Bohemian Rhapsody     Universal              11              1
# 475                       Trench        Warner              12              1
# 577                Os Pintainhos  Farol Musica               0              2
# 678                   This Is It    Sony Music              10              2
# 686    Cumplicidade a duas vozes  Farol Musica               1              2
# 791           Unorthodox Jukebox        Warner               9              2
# 934               A Star Is Born     Universal              14              2
# 937            Bohemian Rhapsody     Universal              12              2
# 959                    Vai e vem        Warner              12              2
# 1055               Os Pintainhos  Farol Musica               0              3
# 1068                     Inédito           Emi               0              3
# 1098       A festa dos golfinhos      Sony Bmg              20              3
# 1161   Cumplicidade a duas vozes  Farol Musica               2              3
# 1164                  This Is It    Sony Music              11              3
# 1193               Into The Wild    Sony Music               5              3
# 1218                       PJ 20    Sony Music               9              3
# 1247                  ----------           NaN               0              3
# 1248                  ----------           NaN               0              3
# 1251                  ----------           NaN               0              3
# 1252                        Fade      Popstock               1              3
# 1253                  ----------           NaN               0              3
# 1254                  ----------           NaN               0              3
# 1258                  ----------           NaN               0              3
#
#       year country
# 80    2006     NaN
# 201   2010     NaN
# 208   2010     NaN
# 237   2011     NaN
# 312   2014     NaN
# 389   2016     NaN
# 452   2019     NaN
# 462   2019     NaN
# 475   2019     NaN
# 577   2007     NaN
# 678   2010     NaN
# 686   2010     NaN
# 791   2014     NaN
# 934   2019     NaN
# 937   2019     NaN
# 959   2019    None
# 1055  2007     NaN
# 1068  2007     NaN
# 1098  2008    None
# 1161  2010     NaN
# 1164  2010     NaN
# 1193  2011     NaN
# 1218  2012     NaN
# 1247  2013     NaN
# 1248  2013     NaN
# 1251  2013     NaN
# 1252  2013    None
# 1253  2013     NaN
# 1254  2013     NaN
# 1258  2013     NaN

# %%
newish.loc[newish['artist'] == 'Os Pintainhos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Márcia', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Beto & Ménito', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Soundtrack / Miley Cyrus', 'country'] = 'US'
newish.loc[newish['artist'] == 'Viky', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tom Jobim', 'country'] = 'BR'


newish.loc[newish['artist'] == 'Soundtrack / Michael Jackson', 'country'] = 'US'
newish.loc[newish['artist'] == 'Soundtrack / Eddie Vedder', 'country'] = 'US'
newish.loc[newish['artist'] == 'Soundtrack / Pearl Jam', 'country'] = 'US'
newish.loc[newish['artist'] == 'Soundtrack / Lady Gaga / Bradley Cooper', 'country'] = 'US'
newish.loc[newish['artist'] == 'Twenty One Pilots', 'country'] = 'US'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#       rank previous_week                                             artist  \
# 80      21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 237     28            10  Sting feat. The Royal Philharmonic Concert Orc...
# 312     13            14                                                NaN
# 389     30            37                                 Jardim De Infância
# 462     13             4                                 Soundtrack / Queen
# 791     12            13                                                NaN
# 937      8            13                                 Soundtrack / Queen
# 1247    18            ++                                                NaN
# 1248    19            ++                                                NaN
# 1251    22            ++                                                NaN
# 1252    23           NaN                                        Yo La Tengo
# 1253    24            ++                                                NaN
# 1254    25            ++                                                NaN
# 1258    29            ++                                                NaN
# 1276    17            12                                                NaN
# 1306    17           NaN                          D'Angelo and The Vanguard
# 1350     1           NaN                                             The XX
# 1376    27            47                                    O Mundo Da Sara
# 1403    24            34                                       Ana Bacalhau
# 1414     5             8                                 Soundtrack / Queen
# 1480    11           NaN                   Soundtrack / Andrew Lloyd Webber
# 1526    27            ++                                Escolinha de música
# 1541    12           NaN                                          JP Simões
# 1672    23            ++                             The Legendary Tigerman
# 1709    30            ++                           Luís Represas e João Gil
# 1735    26           NaN                                      The Lumineers
# 1736    27            23                                        Yo La Tengo
# 1737    28            ++                                             The XX
# 1753    14            17                                                NaN
# 1755    16           NaN                       You Can't Win, Charlie Brown
#
#                          album           label  weeks_on_chart  calendar_week  \
# 80             Christmas Songs           Verve               9              1
# 237             Live In Berlin       Universal               5              1
# 312         Unorthodox Jukebox          Warner               8              1
# 389         Jardim De Infância        Espacial               0              1
# 462          Bohemian Rhapsody       Universal              11              1
# 791         Unorthodox Jukebox          Warner               9              2
# 937          Bohemian Rhapsody       Universal              12              2
# 1247                ----------             NaN               0              3
# 1248                ----------             NaN               0              3
# 1251                ----------             NaN               0              3
# 1252                      Fade        Popstock               1              3
# 1253                ----------             NaN               0              3
# 1254                ----------             NaN               0              3
# 1258                ----------             NaN               0              3
# 1276        Unorthodox Jukebox          Warner              10              3
# 1306             Black Messiah      Sony Music               1              3
# 1350                 I See You        Popstock               1              3
# 1376           O Mundo Da Sara       Universal              10              3
# 1403              Nome próprio       Universal              13              3
# 1414         Bohemian Rhapsody       Universal              13              3
# 1480  The Phantom Of The Opera  Sony Classical               1              4
# 1526       Escolinha de música    Farol Musica              40              4
# 1541                      1970              Vc               0              4
# 1672                    Femina             Emi              20              4
# 1709  Luís Represas e João Gil             Emi               5              4
# 1735             The Lumineers       Universal               1              4
# 1736                      Fade        Popstock               2              4
# 1737                   Coexist        Popstock              11              4
# 1753        Unorthodox Jukebox          Warner              11              4
# 1755  Diffraction / Refraction       Altafonte               1              4
#
#       year country
# 80    2006     NaN
# 237   2011     NaN
# 312   2014     NaN
# 389   2016     NaN
# 462   2019     NaN
# 791   2014     NaN
# 937   2019     NaN
# 1247  2013     NaN
# 1248  2013     NaN
# 1251  2013     NaN
# 1252  2013    None
# 1253  2013     NaN
# 1254  2013     NaN
# 1258  2013     NaN
# 1276  2014     NaN
# 1306  2015     NaN
# 1350  2017     NaN
# 1376  2017     NaN
# 1403  2018    None
# 1414  2019     NaN
# 1480  2005     NaN
# 1526  2006     NaN
# 1541  2007    None
# 1672  2011    None
# 1709  2012     NaN
# 1735  2013    None
# 1736  2013    None
# 1737  2013     NaN
# 1753  2014     NaN
# 1755  2014     NaN

# %%
newish.loc[newish['artist'] == 'Ana Bacalhau', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Luís Represas e João Gil', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Escolinha de música', 'country'] = 'PT'
newish.loc[newish['artist'] == 'JP Simões', 'country'] = 'PT'
newish.loc[newish['artist'] == 'O Mundo Da Sara', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Jardim De Infância', 'country'] = 'PT'
newish.loc[newish['artist'] == 'You Can\'t Win, Charlie Brown', 'country'] = 'PT'


newish.loc[newish['artist'] == 'D\'Angelo and The Vanguard 	', 'country'] = 'US'
newish.loc[newish['artist'] == 'The XX', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Soundtrack / Queen', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Soundtrack / Andrew Lloyd Webber', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Yo La Tengo', 'country'] = 'US'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#       rank previous_week                                             artist  \
# 80      21             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 237     28            10  Sting feat. The Royal Philharmonic Concert Orc...
# 312     13            14                                                NaN
# 791     12            13                                                NaN
# 1247    18            ++                                                NaN
# 1248    19            ++                                                NaN
# 1251    22            ++                                                NaN
# 1253    24            ++                                                NaN
# 1254    25            ++                                                NaN
# 1258    29            ++                                                NaN
# 1276    17            12                                                NaN
# 1306    17           NaN                          D'Angelo and The Vanguard
# 1672    23            ++                             The Legendary Tigerman
# 1735    26           NaN                                      The Lumineers
# 1753    14            17                                                NaN
# 1769    30           NaN                                       Filipe Pinto
# 1786    17           NaN                                Belle And Sebastian
# 1803     4           NaN                      Caetano Veloso / Gilberto Gil
# 1861     2           NaN                             The Legendary Tigerman
# 1979    30            ++                                         Joss Stone
# 2147    18            23                             The Legendary Tigerman
# 2153    24            ++                                   Joka Fantasminha
# 2158    29            ++  Sting feat. The Royal Philharmonic Concert Orc...
# 2184    25            ++                             Florence + The Machine
# 2203    14           NaN                                    Helder Moutinho
# 2205    16           NaN                                           Ana Free
# 2208    19           NaN                        Manuel Fúria E Os Náufragos
# 2213    24           NaN                                               Kalu
# 2237    18            14                                                NaN
# 2243    24           NaN                                              Mallu
#
#                                           album         label  weeks_on_chart  \
# 80                              Christmas Songs         Verve               9
# 237                              Live In Berlin     Universal               5
# 312                          Unorthodox Jukebox        Warner               8
# 791                          Unorthodox Jukebox        Warner               9
# 1247                                 ----------           NaN               0
# 1248                                 ----------           NaN               0
# 1251                                 ----------           NaN               0
# 1253                                 ----------           NaN               0
# 1254                                 ----------           NaN               0
# 1258                                 ----------           NaN               0
# 1276                         Unorthodox Jukebox        Warner              10
# 1306                              Black Messiah    Sony Music               1
# 1672                                     Femina           Emi              20
# 1735                              The Lumineers     Universal               1
# 1753                         Unorthodox Jukebox        Warner              11
# 1769                              Planeta limpo  Farol Musica               1
# 1786           Girls In Peacetime Want To Dance      Popstock               1
# 1803           Dois amigos, um século de música     Universal               1
# 1861                                     Misfit    Sony Music               1
# 1979                           Mind Body & Soul        Virgin               8
# 2147                                     Femina           Emi              21
# 2153                              Tudo numa boa    Sony Music               5
# 2158                             Live In Berlin     Universal               6
# 2184                                Ceremonials     Universal               5
# 2203                                       1987           Evc               1
# 2205                                 To.get.her           Evc               1
# 2208  Manuel Fúria contempla os lirios do campo           Evc               1
# 2213                                Comunicação     Universal               1
# 2237                         Unorthodox Jukebox        Warner              12
# 2243                                    Pitanga    Sony Music               1
#
#       calendar_week  year country
# 80                1  2006     NaN
# 237               1  2011     NaN
# 312               1  2014     NaN
# 791               2  2014     NaN
# 1247              3  2013     NaN
# 1248              3  2013     NaN
# 1251              3  2013     NaN
# 1253              3  2013     NaN
# 1254              3  2013     NaN
# 1258              3  2013     NaN
# 1276              3  2014     NaN
# 1306              3  2015     NaN
# 1672              4  2011    None
# 1735              4  2013    None
# 1753              4  2014     NaN
# 1769              4  2014    None
# 1786              4  2015     NaN
# 1803              4  2016     NaN
# 1861              4  2018    None
# 1979              5  2005    None
# 2147              5  2011    None
# 2153              5  2011     NaN
# 2158              5  2011     NaN
# 2184              5  2012     NaN
# 2203              5  2013     NaN
# 2205              5  2013    None
# 2208              5  2013     NaN
# 2213              5  2013    None
# 2237              5  2014     NaN
# 2243              5  2014     NaN

# %%
newish.loc[newish['artist'] == 'Ana Free', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Helder Moutinho', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Manuel Fúria E Os Náufragos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Filipe Pinto', 'country'] = 'PT'
newish.loc[newish['artist'] == 'The Legendary Tigerman', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Joka Fantasminha', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Kalu', 'country'] = 'PT'


newish.loc[newish['artist'] == 'D\'Angelo and The Vanguard', 'country'] = 'US'
newish.loc[newish['artist'] == 'The Lumineers', 'country'] = 'US'
newish.loc[newish['artist'] == 'Florence + The Machine', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Joss Stone', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Belle And Sebastian', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Caetano Veloso / Gilberto Gil', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Mallu', 'country'] = 'BR'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.tail(30)
# Out:
#        rank previous_week                                             artist  \
# 23659    20            20                                                NaN
# 23729    30            22                             Frei Hermano Da Câmara
# 23877    28           NaN                              Soundtrack / Vangelis
# 23885     6             5  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 23953    14            11                       Teresa Salgueiro & Lusitânia
# 23966    27            25                                        Pedro Khima
# 24040    11            18                        Soundtrack / Hannah Montana
# 24046    17            22  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 24057    28            21  Sting feat. The Royal Philharmonic Concert Orc...
# 24106    17            14                 Maria João Pires / Carlos do Carmo
# 24119    30            ++                                 Ricardo Reis Pinto
# 24139    20            20                                                NaN
# 24179    30           NaN                                5 Seconds Of Summer
# 24209    30            30                             Frei Hermano Da Câmara
# 24233    24            34                  Dead Combo E As Cordas Da Má Fama
# 24267    28            37                                                NaN
# 24365     6             6  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 24443    24            14                       Teresa Salgueiro & Lusitânia
# 24445    26            27                                        Pedro Khima
# 24527    18            11                        Soundtrack / Hannah Montana
# 24529    20            28  Sting feat. The Royal Philharmonic Concert Orc...
# 24537    28            17  Diana Krall feat. The Clayton/Hamilton Jazz Or...
# 24562    23            ++                               Caetano e Maria Gadú
# 24585    16            17                 Maria João Pires / Carlos do Carmo
# 24591    22            ++                                                NaN
# 24598    29            ++                                                NaN
# 24599    30            ++                                                NaN
# 24613    14            20                                                NaN
# 24659    30            30                                5 Seconds Of Summer
# 24685    26            ++                                5 Seconds Of Summer
#
#                                     album           label  weeks_on_chart  \
# 23659                  Unorthodox Jukebox          Warner               5
# 23729                          O nazareno      Sony Music               2
# 23877                           Alexander  Sony Classical               1
# 23885                     Christmas Songs           Verve               7
# 23953                           La serena     Farol Music               8
# 23966                         Pedro Khima    Farol Musica              15
# 24040              Hannah Montana Forever             Emi               8
# 24046                     Christmas Songs       Universal              12
# 24057                      Live In Berlin       Universal               2
# 24106  Maria João Pires / Carlos do Carmo       Universal               3
# 24119                             Vem daí             Evc               2
# 24139                  Unorthodox Jukebox          Warner               6
# 24179                             Livesos       Universal               1
# 24209                          O nazareno      Sony Music               3
# 24233                          Dead Combo       Universal               4
# 24267                     João Gil por...          Warner              10
# 24365                     Christmas Songs           Verve               8
# 24443                           La serena     Farol Music               9
# 24445                         Pedro Khima    Farol Musica              16
# 24527              Hannah Montana Forever             Emi               9
# 24529                      Live In Berlin       Universal               3
# 24537                     Christmas Songs       Universal              13
# 24562                   Multishow ao vivo       Universal              11
# 24585  Maria João Pires / Carlos do Carmo       Universal               4
# 24591                          ----------             NaN               0
# 24598                          ----------             NaN               0
# 24599                          ----------             NaN               0
# 24613                  Unorthodox Jukebox          Warner               7
# 24659                             Livesos       Universal               2
# 24685              Sounds Good Feels Good       Universal               5
#
#        calendar_week  year country
# 23659             50  2013     NaN
# 23729             50  2015     NaN
# 23877             51  2004     NaN
# 23885             51  2005     NaN
# 23953             51  2007     NaN
# 23966             51  2007    None
# 24040             51  2010     NaN
# 24046             51  2010     NaN
# 24057             51  2010     NaN
# 24106             51  2012     NaN
# 24119             51  2012     NaN
# 24139             51  2013     NaN
# 24179             51  2014     NaN
# 24209             51  2015     NaN
# 24233             51  2016     NaN
# 24267             51  2017     NaN
# 24365             52  2005     NaN
# 24443             52  2007     NaN
# 24445             52  2007    None
# 24527             52  2010     NaN
# 24529             52  2010     NaN
# 24537             52  2010     NaN
# 24562             52  2011     NaN
# 24585             52  2012     NaN
# 24591             52  2012     NaN
# 24598             52  2012     NaN
# 24599             52  2012     NaN
# 24613             52  2013     NaN
# 24659             52  2014     NaN
# 24685             52  2015     NaN

# %%
newish.loc[newish['artist'] == 'Teresa Salgueiro & Lusitânia', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Pedro Khima', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Dead Combo E As Cordas Da Má Fama', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Frei Hermano Da Câmara', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria João Pires / Carlos do Carmo', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Sting feat. The Royal Philharmonic Concert Orchestra', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Soundtrack / Hannah Montana', 'country'] = 'US'
newish.loc[newish['artist'] == '5 Seconds Of Summer', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Diana Krall feat. The Clayton/Hamilton Jazz Orchestra', 'country'] = 'US'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.tail(30)
# Out:
#        rank previous_week                                             artist  \
# 22763    24            14                          Soundtrack / Roger Waters
# 22853    24            19                                      Diabo Na Cruz
# 22888    29           NaN  Rod Stewart with The Royal Philharmonic Orchestra
# 22939    20            15                                   System Of A Down
# 22946    27            21                                    Nat "King" Cole
# 23055    16            20                                           LazyTown
# 23063    24           NaN                                        Bossa Nossa
# 23086    17            17                        Rodrigo Leão & Vox Ensemble
# 23099    30           NaN                Coro Infantil Santo Amaro de Oeiras
# 23129    30            17                               Caetano e Maria Gadú
# 23151    22           NaN                                 Ricardo Reis Pinto
# 23153    24            20                                           Tim [PT]
# 23179    20            18                                                NaN
# 23188    29            ++                                      Júlio Resende
# 23189    30            ++                                        Miley Cyrus
# 23336    27            24                                      Diabo Na Cruz
# 23537    18           NaN                                   O Mundo de Patty
# 23545    26            16                                           LazyTown
# 23573    24            30                Coro Infantil Santo Amaro de Oeiras
# 23574    25            17                        Rodrigo Leão & Vox Ensemble
# 23659    20            20                                                NaN
# 23877    28           NaN                              Soundtrack / Vangelis
# 24119    30            ++                                 Ricardo Reis Pinto
# 24139    20            20                                                NaN
# 24267    28            37                                                NaN
# 24562    23            ++                               Caetano e Maria Gadú
# 24591    22            ++                                                NaN
# 24598    29            ++                                                NaN
# 24599    30            ++                                                NaN
# 24613    14            20                                                NaN
#
#                                 album           label  weeks_on_chart  \
# 22763           Roger Waters The Wall      Sony Music               2
# 22853                           Lebre      Sony Music               7
# 22888              You're In My Heart          Warner               1
# 22939                       Hypnotize        Columbia               2
# 22946        Nat King Cole en español         Capitol              11
# 23055                        LazyTown           Iplay               2
# 23063                Mais Bossa Nossa      Sony Music               1
# 23086               Ave mundi luminar      Sony Music               5
# 23099                      Já é Natal         Vidisco               1
# 23129               Multishow ao vivo       Universal              10
# 23151                         Vem daí             Evc               1
# 23153  Tim e companheiros de aventura    Farol Musica               5
# 23179              Unorthodox Jukebox          Warner               4
# 23188        Amália por Júlio Resende             Evc               7
# 23189                         Bangerz      Sony Music               5
# 23336                           Lebre      Sony Music               8
# 23537                O Mundo de Patty             Emi               1
# 23545                        LazyTown           Iplay               3
# 23573                      Já é Natal         Vidisco               2
# 23574               Ave mundi luminar      Sony Music               6
# 23659              Unorthodox Jukebox          Warner               5
# 23877                       Alexander  Sony Classical               1
# 24119                         Vem daí             Evc               2
# 24139              Unorthodox Jukebox          Warner               6
# 24267                 João Gil por...          Warner              10
# 24562               Multishow ao vivo       Universal              11
# 24591                      ----------             NaN               0
# 24598                      ----------             NaN               0
# 24599                      ----------             NaN               0
# 24613              Unorthodox Jukebox          Warner               7
#
#        calendar_week  year country
# 22763             48  2015     NaN
# 22853             48  2018     NaN
# 22888             48  2019     NaN
# 22939             49  2005     NaN
# 22946             49  2005     NaN
# 23055             49  2009    None
# 23063             49  2009     NaN
# 23086             49  2010     NaN
# 23099             49  2010     NaN
# 23129             49  2011     NaN
# 23151             49  2012     NaN
# 23153             49  2012     NaN
# 23179             49  2013     NaN
# 23188             49  2013    None
# 23189             49  2013    None
# 23336             49  2018     NaN
# 23537             50  2009     NaN
# 23545             50  2009    None
# 23573             50  2010     NaN
# 23574             50  2010     NaN
# 23659             50  2013     NaN
# 23877             51  2004     NaN
# 24119             51  2012     NaN
# 24139             51  2013     NaN
# 24267             51  2017     NaN
# 24562             52  2011     NaN
# 24591             52  2012     NaN
# 24598             52  2012     NaN
# 24599             52  2012     NaN
# 24613             52  2013     NaN

# %%
newish.loc[newish['artist'] == 'Caetano e Maria Gadú', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Diabo Na Cruz', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Ricardo Reis Pinto', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rodrigo Leão & Vox Ensemble', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Coro Infantil Santo Amaro de Oeiras', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tim [PT]', 'country'] = 'PT'

newish.loc[newish['artist'] == 'System Of A Down', 'country'] = 'US'
newish.loc[newish['artist'] == 'Miley Cyrus', 'country'] = 'US'
newish.loc[newish['artist'] == 'Soundtrack / Roger Waters', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Nat "King" Cole', 'country'] = 'US'
newish.loc[newish['artist'] == 'Rod Stewart with The Royal Philharmonic Orchestra', 'country'] = 'GB'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.tail(30)
# Out:
#        rank previous_week                                             artist  \
# 22070    21            14                         Maria João & Mário Laginha
# 22078    29            ++                                            Per7ume
# 22120    11           NaN                                            Per7ume
# 22126    17            ++                                        Adriana Lua
# 22211    12            12                                                NaN
# 22222    23            23                                            Némanus
# 22254    25            17                                    Kátia Guerreiro
# 22276    17           NaN                                               Átoa
# 22293     4           NaN                                      Força Suprema
# 22313    24            12                       Rodrigo Leão & Scott Matthew
# 22340    21           NaN  Aretha Franklin with The Royal Philharmonic Or...
# 22369    20           NaN                                              Paião
# 22403    24            22                     Soundtrack / Bruce Springsteen
# 22579    20           NaN                                           LazyTown
# 22697    18            12                                                NaN
# 22706    27            23                                            Némanus
# 23055    16            20                                           LazyTown
# 23063    24           NaN                                        Bossa Nossa
# 23179    20            18                                                NaN
# 23188    29            ++                                      Júlio Resende
# 23537    18           NaN                                   O Mundo de Patty
# 23545    26            16                                           LazyTown
# 23659    20            20                                                NaN
# 23877    28           NaN                              Soundtrack / Vangelis
# 24139    20            20                                                NaN
# 24267    28            37                                                NaN
# 24591    22            ++                                                NaN
# 24598    29            ++                                                NaN
# 24599    30            ++                                                NaN
# 24613    14            20                                                NaN
#
#                                      album            label  weeks_on_chart  \
# 22070                            Chocolate        Universal               2
# 22078                              Per7ume  Vidisco/nz Prod              14
# 22120                                 Mudo          Vidisco               1
# 22126                          Adriana Lua         Espacial               3
# 22211                   Unorthodox Jukebox           Warner               2
# 22222                  O melhor de Némanus         Espacial              19
# 22254                           Até ao fim  Compact Records               2
# 22276                  Idade dos inquietos        Universal               1
# 22293                E a união faz a força       Sony Music               1
# 22313                         Life Is Long        Universal               8
# 22340                       A Brand New Me           Warner               1
# 22369                                Paião       Sony Music               1
# 22403  Western Stars - Songs From The Film       Sony Music               4
# 22579                             LazyTown            Iplay               1
# 22697                   Unorthodox Jukebox           Warner               3
# 22706                  O melhor de Némanus         Espacial              20
# 23055                             LazyTown            Iplay               2
# 23063                     Mais Bossa Nossa       Sony Music               1
# 23179                   Unorthodox Jukebox           Warner               4
# 23188             Amália por Júlio Resende              Evc               7
# 23537                     O Mundo de Patty              Emi               1
# 23545                             LazyTown            Iplay               3
# 23659                   Unorthodox Jukebox           Warner               5
# 23877                            Alexander   Sony Classical               1
# 24139                   Unorthodox Jukebox           Warner               6
# 24267                      João Gil por...           Warner              10
# 24591                           ----------              NaN               0
# 24598                           ----------              NaN               0
# 24599                           ----------              NaN               0
# 24613                   Unorthodox Jukebox           Warner               7
#
#        calendar_week  year country
# 22070             47  2008     NaN
# 22078             47  2008    None
# 22120             47  2010    None
# 22126             47  2010    None
# 22211             47  2013     NaN
# 22222             47  2013    None
# 22254             47  2014     NaN
# 22276             47  2015     NaN
# 22293             47  2016     NaN
# 22313             47  2016     NaN
# 22340             47  2017     NaN
# 22369             47  2018     NaN
# 22403             47  2019     NaN
# 22579             48  2009    None
# 22697             48  2013     NaN
# 22706             48  2013    None
# 23055             49  2009    None
# 23063             49  2009     NaN
# 23179             49  2013     NaN
# 23188             49  2013    None
# 23537             50  2009     NaN
# 23545             50  2009    None
# 23659             50  2013     NaN
# 23877             51  2004     NaN
# 24139             51  2013     NaN
# 24267             51  2017     NaN
# 24591             52  2012     NaN
# 24598             52  2012     NaN
# 24599             52  2012     NaN
# 24613             52  2013     NaN

# %%
newish.loc[newish['artist'] == 'Júlio Resende', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Paião', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Átoa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Kátia Guerreiro', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Rodrigo Leão & Scott Matthew', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Per7ume', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria João & Mário Laginha', 'country'] = 'PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.tail(30)
# Out:
#        rank previous_week                                             artist  \
# 21907     8           NaN                                          FKA Twigs
# 21920    21            21                                            C4pedro
# 21921    22            10                     Soundtrack / Bruce Springsteen
# 21923    24           NaN                                         The Script
# 21958    29            23                          Céline Dion & Anne Geddes
# 22015    26           NaN                                  Clavezinha De Sol
# 22032    13            ++                                            Némanus
# 22068    19            16                        Madredeus & A Banda Cósmica
# 22126    17            ++                                        Adriana Lua
# 22211    12            12                                                NaN
# 22222    23            23                                            Némanus
# 22293     4           NaN                                      Força Suprema
# 22340    21           NaN  Aretha Franklin with The Royal Philharmonic Or...
# 22403    24            22                     Soundtrack / Bruce Springsteen
# 22579    20           NaN                                           LazyTown
# 22697    18            12                                                NaN
# 22706    27            23                                            Némanus
# 23055    16            20                                           LazyTown
# 23063    24           NaN                                        Bossa Nossa
# 23179    20            18                                                NaN
# 23537    18           NaN                                   O Mundo de Patty
# 23545    26            16                                           LazyTown
# 23659    20            20                                                NaN
# 23877    28           NaN                              Soundtrack / Vangelis
# 24139    20            20                                                NaN
# 24267    28            37                                                NaN
# 24591    22            ++                                                NaN
# 24598    29            ++                                                NaN
# 24599    30            ++                                                NaN
# 24613    14            20                                                NaN
#
#                                      album           label  weeks_on_chart  \
# 21907                            Magdalene        Popstock               1
# 21920                        The Gentleman      Sony Music               4
# 21921  Western Stars - Songs From The Film      Sony Music               3
# 21923                 Sunsets & Full Moons      Sony Music               1
# 21958                              Miracle        Columbia               4
# 22015          A musica dos brinquedos III         Vidisco               0
# 22032                     Dançando kizomba        Espacial               2
# 22068                            Metafonia    Farol Musica               4
# 22126                          Adriana Lua        Espacial               3
# 22211                   Unorthodox Jukebox          Warner               2
# 22222                  O melhor de Némanus        Espacial              19
# 22293                E a união faz a força      Sony Music               1
# 22340                       A Brand New Me          Warner               1
# 22403  Western Stars - Songs From The Film      Sony Music               4
# 22579                             LazyTown           Iplay               1
# 22697                   Unorthodox Jukebox          Warner               3
# 22706                  O melhor de Némanus        Espacial              20
# 23055                             LazyTown           Iplay               2
# 23063                     Mais Bossa Nossa      Sony Music               1
# 23179                   Unorthodox Jukebox          Warner               4
# 23537                     O Mundo de Patty             Emi               1
# 23545                             LazyTown           Iplay               3
# 23659                   Unorthodox Jukebox          Warner               5
# 23877                            Alexander  Sony Classical               1
# 24139                   Unorthodox Jukebox          Warner               6
# 24267                      João Gil por...          Warner              10
# 24591                           ----------             NaN               0
# 24598                           ----------             NaN               0
# 24599                           ----------             NaN               0
# 24613                   Unorthodox Jukebox          Warner               7
#
#        calendar_week  year country
# 21907             46  2019     NaN
# 21920             46  2019     NaN
# 21921             46  2019     NaN
# 21923             46  2019    None
# 21958             47  2004     NaN
# 22015             47  2006     NaN
# 22032             47  2007    None
# 22068             47  2008    None
# 22126             47  2010    None
# 22211             47  2013     NaN
# 22222             47  2013    None
# 22293             47  2016     NaN
# 22340             47  2017     NaN
# 22403             47  2019     NaN
# 22579             48  2009    None
# 22697             48  2013     NaN
# 22706             48  2013    None
# 23055             49  2009    None
# 23063             49  2009     NaN
# 23179             49  2013     NaN
# 23537             50  2009     NaN
# 23545             50  2009    None
# 23659             50  2013     NaN
# 23877             51  2004     NaN
# 24139             51  2013     NaN
# 24267             51  2017     NaN
# 24591             52  2012     NaN
# 24598             52  2012     NaN
# 24599             52  2012     NaN
# 24613             52  2013     NaN

# %%
newish.loc[newish['artist'] == 'Adriana Lua', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Némanus', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Força Suprema', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Madredeus & A Banda Cósmica', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Clavezinha De Sol', 'country'] = 'PT'

newish.loc[newish['artist'] == 'The Script', 'country'] = 'IE'
newish.loc[newish['artist'] == 'Miley Cyrus', 'country'] = 'US'
newish.loc[newish['artist'] == 'FKA Twigs', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Soundtrack / Bruce Springsteen', 'country'] = 'US'
newish.loc[newish['artist'] == 'Soundtrack / Vangelis', 'country'] = 'GR'

# %%
newish.isna().sum()
# Out:
# rank                 0
# previous_week     2475
# artist              55
# album                0
# label               57
# weeks_on_chart       0
# calendar_week        0
# year                 0
# country           1508
# dtype: int64

# %%
fix_nation = newish.loc[newish['country'].isnull()]
fix_nation.head(30)
# Out:
#       rank previous_week                           artist  \
# 312     13            14                              NaN
# 791     12            13                              NaN
# 1247    18            ++                              NaN
# 1248    19            ++                              NaN
# 1251    22            ++                              NaN
# 1253    24            ++                              NaN
# 1254    25            ++                              NaN
# 1258    29            ++                              NaN
# 1276    17            12                              NaN
# 1753    14            17                              NaN
# 2237    18            14                              NaN
# 2282     3           NaN                    Dream Theater
# 2301    22           NaN                     Caelums Edge
# 2316     7           NaN              Padre Fabio De Melo
# 2337    28           NaN                         3 Marias
# 2364    25            47                 Alexander Search
# 2377     8           NaN             Bring Me The Horizon
# 2468     9           NaN                      Simone [IT]
# 2526     7           NaN   Sérgio Godinho & Os Assessores
# 2535    16           NaN                     Carnaval Mix
# 2537    18           NaN      Alex Amaral e Sandra Coelho
# 2560    11           NaN  Roberto Carlos e Caetano Veloso
# 2570    21           NaN                      Bossa Nossa
# 2713    14            18                              NaN
# 2723    24           NaN          Pat Metheny Unity Group
# 2748    19           NaN                     Pedro Mestre
# 2777    18             3                    Dream Theater
# 2798     9           NaN                 União Das Tribos
# 2814    25            37         Capicua & Pedro Geraldes
# 2820     1           NaN                      Paulo Sousa
#
#                                                 album            label  \
# 312                                Unorthodox Jukebox           Warner
# 791                                Unorthodox Jukebox           Warner
# 1247                                       ----------              NaN
# 1248                                       ----------              NaN
# 1251                                       ----------              NaN
# 1253                                       ----------              NaN
# 1254                                       ----------              NaN
# 1258                                       ----------              NaN
# 1276                               Unorthodox Jukebox           Warner
# 1753                               Unorthodox Jukebox           Warner
# 2237                               Unorthodox Jukebox           Warner
# 2282                                  The Astonishing       Sony Music
# 2301                                           Enigma       Sony Music
# 2316                     Deus no esconderijo do verso       Sony Music
# 2337                                           Depois       Sony Music
# 2364                                 Alexander Search       Sony Music
# 2377                                              Amo       Sony Music
# 2468                                   Simone ao vivo              Emi
# 2526                       Nove e meia no Maria Matos    Emi/universal
# 2535                             O melhor do carnaval          Vidisco
# 2537                             O melhor do carnaval         Espacial
# 2560                          E a musica de Tom Jobim       Sony Music
# 2570  O melhor da pop portuguesa, em ritmo bossa nova       Sony Music
# 2713                               Unorthodox Jukebox           Warner
# 2723                                           Kin ()           Warner
# 2748                            Campaniça do despique  Compact Records
# 2777                                  The Astonishing       Sony Music
# 2798                                           Amanhã  Compact Records
# 2814                                        Mão verde              Evc
# 2820                                              Teu       Sony Music
#
#       weeks_on_chart  calendar_week  year country
# 312                8              1  2014     NaN
# 791                9              2  2014     NaN
# 1247               0              3  2013     NaN
# 1248               0              3  2013     NaN
# 1251               0              3  2013     NaN
# 1253               0              3  2013     NaN
# 1254               0              3  2013     NaN
# 1258               0              3  2013     NaN
# 1276              10              3  2014     NaN
# 1753              11              4  2014     NaN
# 2237              12              5  2014     NaN
# 2282               1              5  2016    None
# 2301               1              5  2016     NaN
# 2316               1              5  2017     NaN
# 2337               1              5  2017     NaN
# 2364              17              5  2018     NaN
# 2377               1              5  2019     NaN
# 2468               1              6  2006     NaN
# 2526               1              6  2008    None
# 2535               1              6  2008     NaN
# 2537               1              6  2008     NaN
# 2560               1              6  2009     NaN
# 2570               1              6  2009     NaN
# 2713              13              6  2014     NaN
# 2723               1              6  2014    None
# 2748               1              6  2015     NaN
# 2777               2              6  2016    None
# 2798               1              6  2017     NaN
# 2814              17              6  2017     NaN
# 2820               1              6  2018     NaN

# %%
newish.loc[newish['artist'] == 'Roberto Carlos e Caetano Veloso', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Sérgio Godinho & Os Assessores', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Capicua & Pedro Geraldes', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Paulo Sousa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Pedro Mestre', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Alex Amaral e Sandra Coelho', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Alexander Search', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Caelums Edge', 'country'] = 'PT'
newish.loc[newish['artist'] == 'União Das Tribos', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Dream Theater', 'country'] = 'US'
newish.loc[newish['artist'] == 'Bring Me The Horizon', 'country'] = 'GB'
newish.loc[newish['artist'] == '5 Seconds of Summer', 'country'] = 'AU'

# %%
newish.loc[newish['artist'] == 'Luka [BR]', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Xeg', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Ruca', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mazgani', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Stereossauro', 'country'] = 'PT'
newish.loc[newish['artist'] == '3 Marias', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Padre Fabio De Melo', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Paus [PT] 	', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Bruno Mendez', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Bruno Mars', 'country'] = 'US'

# %%
newish.loc[newish['album'] == 'Unorthodox Jukebox', 'artist'] = 'Bruno Mars'

# %%
newish.loc[newish['artist'] == 'Roberto Carlos e Caetano Veloso', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Amelia Muge', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Ala Dos Namorados', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Kika', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Jimmy P', 'country'] = 'PT'
newish.loc[newish['artist'] == 'More Than A Thousand', 'country'] = 'PT'
newish.loc[newish['artist'] == 'HMB', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Músicas Infantis', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mão Morta & Remix Ensemble', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Car Seat Headrest', 'country'] = 'US'
newish.loc[newish['artist'] == 'Jack Johnson and Friends', 'country'] = 'US'
newish.loc[newish['artist'] == 'Atoms For Peace', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Lodovica Comello', 'country'] = 'IT'
newish.loc[newish['artist'] == 'Massive Attack', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Rag\'n\'Bone Man', 'country'] = 'GB'

# %%
newish.loc[newish['artist'] == 'Pedro Vaz', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Escola Do Panda', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Marta Ren & The Groovevelts', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Anaquim', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Capicua', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Sónia Araújo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Francisco José', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Toranja', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Cindy Kat', 'country'] = 'PT'
newish.loc[newish['artist'] == 'EZ Special', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Manuel Fúria e Os Naufragos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Carochinha', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Oquestrada', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Missy M', 'country'] = 'PT'

# %%
newish.isna().sum()
# Out:
# rank                 0
# previous_week     2475
# artist              38
# album                0
# label               57
# weeks_on_chart       0
# calendar_week        0
# year                 0
# country           1098
# dtype: int64

# %%
newish.loc[newish['artist'] == '4Kids', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Adiafa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Alfa [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria Lisboa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Marta Peneda', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Marta Pereira Da Costa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Maria João Pires / Claudio Abbad', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Aguias Vermelhas', 'country'] = 'PT'

# %%
newish.loc[newish['artist'] == 'Allana Parker', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Adriana [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Algodao', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Augusto Canário & Amigos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Ana Bacalhau / Jorge Benvinda / Sérgio Godinho / Vitorino 	', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Banda do Panda', 'country'] = 'PT'
newish.loc[newish['artist'] == 'BandaLusa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Bandalusa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Antonio Pinho Vargas', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Alt-J', 'country'] = 'GB'

# %%
newish.loc[newish['artist'] == 'Boy Teddy', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Canta Bahia', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Caetano Veloso / Moreno Veloso / Zeca Veloso / Tom Veloso', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Beth Gibbons And The Polish National Radio Symphony Orchestra / Krzysztof Penderecki', 'country'] = 'GB'
newish.loc[newish['artist'] == 'Ana Bacalhau / Jorge Benvinda / Sérgio Godinho / Vitorino', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Angel-O', 'country'] = 'PT'
newish.loc[newish['artist'] == 'BandaLusa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Bandalusa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Antonio Pinho Vargas', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Ben Harper & The Blind Boys Of Alabama', 'country'] = 'US'
newish.loc[newish['artist'] == 'Ben Harper And Relentless7', 'country'] = 'US'
newish.loc[newish['artist'] == 'Ben Harper and Charlie Musselwhite', 'country'] = 'US'
newish.loc[newish['artist'] == 'Ben Harper', 'country'] = 'US'
newish.loc[newish['artist'] == 'Alice In Chains', 'country'] = 'US'

# %%
newish.loc[newish['artist'] == 'Cidinho e Doca', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Carolina', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Brass Wire Orchestra', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tony De Matos', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tiago Bettencourt & Mantha', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tereza Salgueiro', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Wynton Marsalis & Eric Clapton', 'country'] = 'US'
newish.loc[newish['artist'] == 'Within Temptation & The Metropole Orchestra', 'country'] = 'NL'

# %%
newish.loc[newish['artist'] == 'Fingertips', 'country'] = 'PT'
newish.loc[newish['artist'] == 'FingerTips', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Zé Amaro', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Gabriel O Pensador', 'country'] = 'BR'

newish.loc[newish['artist'] == 'Dário [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Frankie Chavez', 'country'] = 'PT'

# %%
newish.loc[newish['artist'] == 'Super Dragões', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Soundtrack / António Variações', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Sean Riley & The Slowriders', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Tony Bennett & Lady Gaga', 'country'] = 'US'

newish.loc[newish['artist'] == 'Thom Yorke', 'country'] = 'UK'
newish.loc[newish['artist'] == 'Soundtrack / AC/DC', 'country'] = 'AU'

# %%
newish.loc[newish['artist'] == 'Serafim & Companhia', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Soundtrack / António Variações', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Santamaria', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Supernada', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Sangre Ibérico', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Pintainho Amarelinho', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Thom Yorke', 'country'] = 'UK'
newish.loc[newish['artist'] == 'Soundtrack / AC/DC', 'country'] = 'AU'

# %%
newish.loc[newish['artist'] == 'Eddie Vedder', 'country'] = 'US'
newish.loc[newish['artist'] == 'Gotye', 'country'] = 'AU'

# %%
newish.loc[newish['artist'] == 'Kizomba Brasil', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Kizomba Sertanejo', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Pintainho Amarelinho', 'country'] = 'PT'

# %%
newish.loc[newish['artist'] == 'Paus [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Peixe : Avião', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Liliane Marise', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Lena d\'Água', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Leandro E Leonardo', 'country'] = 'BR'

# %%
newish.loc[newish['artist'] == 'Muxima', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mia Rose', 'country'] = 'PT'
newish.loc[newish['artist'] == 'M3 [PT]', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Luisa Sobral', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Vitorino & Janita Salome', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Luis Filipe Reis', 'country'] = 'PT'

# %%
fix_nation = newish.loc[newish['country'].isnull()].groupby(["artist"]).sum()
fix_nation.head(5)
# Out:
#                                                     rank  weeks_on_chart  \
# artist
# Anamar                                                28               1
# André Rieu & His Johann Strauss Orchestra             55               3
# André Viamonte                                        48               3
# Anohni                                                90              12
# Aretha Franklin with The Royal Philharmonic Orc...    42               5
# ...                                                  ...             ...
# Milton Soares                                         27               1
# Mirri Lobo                                            28               1
# Monjes Budistas                                       98               0
# Morangos com Açúcar                                   30               1
# Mundo Cão                                             28               1
#
#                                                     calendar_week   year
# artist
# Anamar                                                         20   2013
# André Rieu & His Johann Strauss Orchestra                      41   4022
# André Viamonte                                                 89   4038
# Anohni                                                         92   8064
# Aretha Franklin with The Royal Philharmonic Orc...             81   4035
# ...                                                           ...    ...
# Milton Soares                                                  23   2005
# Mirri Lobo                                                     10   2019
# Monjes Budistas                                               123  12036
# Morangos com Açúcar                                            13   2010
# Mundo Cão                                                      40   2018
#
# [85 rows x 4 columns]

# %%
newish.loc[newish['artist'] == 'Ladrões Do Tempo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Lingua Franca', 'country'] = 'BR/PT'
newish.loc[newish['artist'] == 'Mesa', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Miguel Angelo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Zé do Pipo', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Mastiksoul', 'country'] = 'PT'

newish.loc[newish['artist'] == 'Maria João Pires / Claudio Abbad', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Martina Stoessel', 'country'] = 'AG'
newish.loc[newish['artist'] == 'Herman José', 'country'] = 'PT'
newish.loc[newish['artist'] == 'Israel Kamakawiwo\'ole', 'country'] = 'US'
newish.loc[newish['artist'] == 'Ivete / Gil / Caetano', 'country'] = 'BR'
newish.loc[newish['artist'] == 'Luis Filipe Reis', 'country'] = 'PT'

# %%
newish.to_csv('newish.csv')
