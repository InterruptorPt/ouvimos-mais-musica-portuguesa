# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dotenv import load_dotenv
from tqdm.notebook import tqdm
import musicbrainzngs

# %%
test_df = pd.read_csv("releases.csv")
test_df["year"] = pd.to_datetime(test_df["year"], errors='coerce')
test_df.dtypes
# Out:
# release_id             int64
# artist                object
# genre                 object
# style                 object
# year          datetime64[ns]
# title                 object
# country               object
# label                 object
# type                  object
# format                object
# dtype: object

# %%
test_df.isnull().sum()
# Out:
# release_id        0
# artist            0
# genre             0
# style             0
# year          13162
# title             0
# country           0
# label             0
# type           1904
# format            0
# dtype: int64

# %%
#total_genre_count = dict(test_df["genre"].value_counts())
#total_genre_count
# Out:
# , 'Latin', 'Funk / Soul', 'Blues', 'Pop', 'Folk, World, & Country']": 2,
#  "['Jazz', 'Reggae', 'Funk / Soul']": 2,
#  "['Rock', 'Reggae', 'Funk / Soul']": 2,
#  "['Classical', 'Brass & Military', 'Stage & Screen']": 2,
#  "['Electronic', 'Latin', 'Classical']": 2,
#  "['Electronic', 'Jazz', 'Funk / Soul', 'Folk, World, & Country']": 2,
#  "['Funk / Soul', 'Pop', 'Classical']": 2,
#  "['Hip Hop', 'Latin', 'Pop']": 2,
#  "['Rock', 'Funk / Soul', 'Blues', 'Folk, World, & Country']": 2,
#  "['Electronic', 'Funk / Soul', 'Pop', 'Classical']": 2,
#  "['Electronic', 'Rock', 'Reggae', 'Pop', 'Folk, World, & Country']": 2,
#  "['Jazz', 'Funk / Soul', 'Blues', 'Pop', 'Classical', 'Folk, World, & Country']": 2,
#  "['Electronic', 'Jazz', 'Rock', 'Latin', 'Folk, World, & Country']": 2,
#  "['Electronic', 'Reggae', 'Latin', 'Pop', 'Folk, World, & Country']": 2,
#  "['Brass & Military', 'Stage & Screen']": 2,
#  "['Funk / Soul', 'Non-Music']": 2,
# ...

# %%
load_dotenv()

musicbrainzngs.auth(os.environ.get("MUSICBRAINZ_USER"), os.environ.get("MUSICBRAINZ_USER"))
musicbrainzngs.set_useragent("chart", 0.1, "https://rute.radio")

# %%
# lista de artistas
unique_artists = list(test_df["artist"].unique())
test_df["artist"].value_counts()
# Out:
# Various              6345
# Amália Rodrigues      526
# José Afonso           217
# Unknown Artist        183
# Roberto Carlos        174
#                      ...
# D'Alma (2)              1
# Angélica                1
# Luís Aleluia            1
# Manuel Campos (2)       1
# Bta F                   1
# Name: artist, Length: 24941, dtype: int64

# %%
new_df = pd.DataFrame()

for artist in tqdm(unique_artists):
    artist_list = musicbrainzngs.search_artists(artist=artist)
    artist_df = pd.DataFrame.from_records(artist_list)
    new_df = pd.concat([new_df, artist_df])
    
print("Já está")
# Out:
# ...
# Já está

# %%
#retirar informação dos dicionários extraídos do musicbrainz


def get_name(x):
    if type(x) == dict:
        return x.get("name")
    
    return "---"

def get_country(x):
    if type(x) == dict:
        return x.get("country")
    
    return "---"
            
new_df["artist"] = new_df["artist-list"].apply(get_name)  
new_df["country"] = new_df["artist-list"].apply(get_country)
new_df
# Out:
#     artist-count                                        artist-list  \
# 0           7403  {'id': '7a198f83-7a9a-4f30-b1f1-7c567ad7292d',...
# 1           7403  {'id': '8b3c7f0f-82f0-413b-be31-d3a5629b6d6e',...
# 2           7403  {'id': 'ba550d0e-adac-4864-b88b-407cab5e76af',...
# 3           7403  {'id': '05517043-ff78-4988-9c22-88c68588ebb9',...
# 4           7403  {'id': 'c4406045-e640-4cfe-8b88-4732cce314d4',...
# ..           ...                                                ...
# 20           246  {'id': '611657b9-a9bb-49e9-b32b-626b76d8c132',...
# 21           246  {'id': '5302b115-4599-46f6-9128-c3a2267062bc',...
# 22           246  {'id': '06f98831-2dde-40cc-bfac-8fd05c83328c',...
# 23           246  {'id': '10fd60da-399b-433d-b55b-1d1ca7476faa',...
# 24           246  {'id': 'f6821c99-2e1b-4f44-bba2-f53d38000073',...
#
#               artist country
# 0          Paul Jays      PT
# 1               JAYS    None
# 2     Paul McCartney      GB
# 3         Paul Simon      US
# ...

# %%
new_df = new_df.drop(['artist-list', "artist-count"], axis=1)

new_df.reset_index(inplace=True)
new_df.drop("index", axis=1, inplace = True)

#new_df.to_csv("musicbrainz_info.csv")

# %%
newish = test_df.merge(new_df, how="left", on='artist')

newish.drop_duplicates(inplace= True)
newish.reset_index(inplace = True)

newish
# Out:
#          index  release_id                       artist  \
# 0            0         122                    Paul Jays
# 1            2        1411                      Various
# 2            3        1415           Homero Bettencourt
# 3           12        4770  Underground Sound Of Lisbon
# 4           13        7304  Underground Sound Of Lisbon
# ...        ...         ...                          ...
# 89974  1161713    16720422     Conjunto Musical Vitória
# 89975  1161714    16722114                      Bruno M
# 89976  1161715    16722345                      Various
# 89977  1161716    16724628               Carla Caramujo
# 89978  1161717    16726167                Chico Buarque
#
#                                           genre                  style  \
# 0                                ['Electronic']              ['House']
# 1                                ['Electronic']             ['Techno']
# 2                                ['Electronic']              ['House']
# ...

# %%
newish.isna().sum()
# Out:
# index             0
# release_id        0
# artist            0
# genre             0
# style             0
# year          13985
# title             0
# country_x         0
# label             0
# type           1994
# format            0
# country_y     51454
# dtype: int64

# %%
newish["artist"].value_counts()
# Out:
# Various                      6345
# Queen                         615
# Amália Rodrigues              526
# Genesis                       332
# The Shadows                   240
#                              ...
# Josep M° Comelles               1
# Elisabeth Engstler              1
# Mickey Mouse And The Gang       1
# DJ Adam Pole                    1
# Bta F                           1
# Name: artist, Length: 24941, dtype: int64

# %% [markdown]
# ## Fixing nationalities

# %%
fix_nation = newish.loc[newish['country_y'].isnull()]
fix_nation["artist"].value_counts()
# Out:
# Various            6345
# Unknown Artist      183
# Carlos Do Carmo     163
# Queen               123
# UHF (2)             123
#                    ...
# Constança (2)         1
# Homero Andrade        1
# Akasa                 1
# Thee Magnets          1
# Bta F                 1
# Name: artist, Length: 18915, dtype: int64

# %%
fix_nation = fix_nation[fix_nation['artist'] != "Various"]
fix_nation = fix_nation[fix_nation['artist'] != "Unknown Artist"]
fix_nation
# Out:
#          index  release_id                           artist  \
# 3           12        4770      Underground Sound Of Lisbon
# 4           13        7304      Underground Sound Of Lisbon
# 12          21       25771                          Maya 13
# 13          22       25772                          Maya 13
# 15          24       27109                      DJ Ze Mig L
# ...        ...         ...                              ...
# 89972  1161711    16716828                       Os Polegar
# 89973  1161712    16718250  Tom Petty And The Heartbreakers
# 89974  1161713    16720422         Conjunto Musical Vitória
# 89975  1161714    16722114                          Bruno M
# 89977  1161716    16724628                   Carla Caramujo
#
#                                           genre                  style  \
# 3                                ['Electronic']  ['Progressive House']
# 4                                ['Electronic']              ['House']
# ...

# %%
fix_nation["artist"].value_counts().head(50)
# Out:
# Carlos Do Carmo                    163
# Queen                              123
# UHF (2)                            123
# Paulo De Carvalho                  114
# Marco Paulo                        111
# Ernesto Rodrigues                  111
# Tony De Matos                      110
# 4 Da People                         92
# A. Paul                             84
# Maria Da Fé                         84
# Genesis                             83
# Frei Hermano Da Câmara              83
# Rodrigo (2)                         77
# Tristão Da Silva                    77
# Delfins                             76
# OCP (2)                             71
# Walt Thisney                        69
# Jorge Fontes                        69
# Neil Diamond                        61
# Conjunto Maria Albertina            60
# ABBA                                59
# Shegundo Galarza                    56
# Pedro Abrunhosa E Os Bandemónio     55
# Adriano Correia De Oliveira         54
# ...

# %%
#fixing nationalities manually

newish.loc[newish['artist'] == 'Carlos Do Carmo', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Queen', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Paulo De Carvalho', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'UHF (2)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Marco Paulo', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Underground Sound Of Lisbon', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'The Gift', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Da Vinci (3)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Spaceboys', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'DJ Ze Mig L', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'A. Paul', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Ernesto Rodrigues', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Tony De Matos', 'country_y'] = 'PT'
newish.loc[newish['artist'] == '4 Da People', 'country_y'] = 'US'
newish.loc[newish['artist'] == 'Maria Da Fé', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Genesis', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Frei Hermano Da Câmara', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Rodrigo (2)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Tristão Da Silva', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Delfins', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'OCP (2)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Walt Thisney', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Jorge Fontes', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Frei Hermano Da Câmara', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Neil Diamond', 'country_y'] = 'US'
newish.loc[newish['artist'] == 'Conjunto Maria Albertina', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Shegundo Galarza', 'country_y'] = 'ES'
newish.loc[newish['artist'] == 'ABBA', 'country_y'] = 'SWE'
newish.loc[newish['artist'] == 'Pedro Abrunhosa E Os Bandemónio', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Jorge Fontes', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Frei Hermano Da Câmara', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Adriano Correia De Oliveira', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Fausto Bordalo Dias', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Heróis Do Mar', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Onda Choc', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Santamaria', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Clemente', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Shirley Bassey', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Leonel Nunes', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Diego Miranda', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'José Barata Moura', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'The Shadows', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Chicago (2)', 'country_y'] = 'US'

# %%
fix_nation = newish.loc[newish['country_y'].isnull()]
fix_nation = fix_nation[fix_nation['artist'] != "Various"]
fix_nation = fix_nation[fix_nation['artist'] != "Unknown Artist"]
fix_nation["artist"].value_counts().head(30)
# Out:
# Conjunto António Mafra                   51
# The Gift (3)                             47
# Florência                                42
# Agrupamento Musical Diapasão             42
# Isidro Baptista                          42
# Conjunto Pai E Filhos                    41
# Tom Jones                                41
# Eugénia Lima                             41
# The Smiths                               40
# Michael Jackson                          40
# Carlos Alberto Moniz                     40
# Lena D'Água                              39
# Manuel De Almeida                        39
# Santana                                  39
# Maria De Lourdes Resende                 39
# Banda Do Casaco                          39
# Tereza Tarouca                           38
# Death In June                            38
# Irae                                     38
# Room Nine Unlimited                      37
# Lena Silva                               37
# ...

# %%
newish.loc[newish['artist'] == 'Conjunto António Mafra', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Tom Jones', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'The Gift (3)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Florência', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Agrupamento Musical Diapasão', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Conjunto Pai E Filhos', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Isidro Baptista', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Eugénia Lima', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'The Smiths', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Michael Jackson', 'country_y'] = 'US'
newish.loc[newish['artist'] == 'Carlos Alberto Moniz', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Lena D\'Água', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Manuel De Almeida', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Santana', 'country_y'] = 'MX'
newish.loc[newish['artist'] == 'Maria De Lourdes Resende', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Banda Do Casaco', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Death In June', 'country_y'] = 'GB'
newish.loc[newish['artist'] == 'Irae', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Room Nine Unlimited', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Lena Silva', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Emanuel (5)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Nilton Cesar', 'country_y'] = 'BR'
newish.loc[newish['artist'] == 'Franck Pourcel Et Son Grand Orchestre', 'country_y'] = 'FR'
newish.loc[newish['artist'] == 'Taxi (8)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'NunSlaughter', 'country_y'] = 'US'
newish.loc[newish['artist'] == 'Francisco José', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Dead Combo (2)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'The Legendary Tiger Man', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Toy (12)', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Maximiano De Sousa', 'country_y'] = 'PT'
newish.loc[newish['artist'] == 'Adriano Correia De Oliveira', 'country_y'] = 'PT'

# %%
fix_nation = newish.loc[newish['country_y'].isnull()]
fix_nation = fix_nation[fix_nation['artist'] != "Various"]
fix_nation = fix_nation[fix_nation['artist'] != "Unknown Artist"]
fix_nation["artist"].value_counts().head(30)
# Out:
# Tereza Tarouca                       38
# Luiz Goes                            34
# Van Morrison                         34
# Frédéric Chopin                      34
# Nuno Da Câmara Pereira               34
# Raphael (2)                          33
# Caetano Veloso                       33
# Maria Clara                          32
# Simone (3)                           32
# Boney M.                             31
# Loudon Kleer                         31
# Brigada Victor Jara                  31
# Filipe de Brito                      31
# Ban (2)                              30
# Pyotr Ilyich Tchaikovsky             30
# Fafá De Belém                        30
# Orchestral Manoeuvres In The Dark    30
# Madness                              29
# João Maria Tudela                    29
# Africa Negra                         29
# Eugénia Melo e Castro                29
# Wings (2)                            29
# Luis Cilia                           29
# ...

# %%
fix_nation
# Out:
#          index  release_id                           artist  \
# 12          21       25771                          Maya 13
# 13          22       25772                          Maya 13
# 17          26       28570                          The The
# 19          28       33833                          DJ Néné
# 20          29       34739                           Precyz
# ...        ...         ...                              ...
# 89972  1161711    16716828                       Os Polegar
# 89973  1161712    16718250  Tom Petty And The Heartbreakers
# 89974  1161713    16720422         Conjunto Musical Vitória
# 89975  1161714    16722114                          Bruno M
# 89977  1161716    16724628                   Carla Caramujo
#
#                                           genre            style       year  \
# 12                               ['Electronic']       ['Tribal']        NaT
# 13                               ['Electronic']       ['Tribal'] 2001-01-01
# ...
